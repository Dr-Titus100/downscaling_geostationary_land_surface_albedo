# %% [markdown]
# ## Loading Packages

# %%
import os
import sys
import glob

# %% [markdown]
# ## Clip path to all helper functions¶

# %%
function_path = os.path.expanduser("~/geoscience/albedo_downscaling/goes_modis_downscaling")
sys.path.append(function_path)
# import all the helper functions.
from plot_fxns import *
from albedo_unet_fxns import *
from data_preprocessing import *

plt.style.use("~/geoscience/carbon_estimation/MNRAS.mplstyle")
# %matplotlib inline

# %% [markdown]
# ## Write all 500m GOES data to a raster

# %%
invalid_dates = []
invalid_dates = convert_dates(INVALID_DATES_PATH)
for date in INVALID_GOES_DATES:
    if date not in invalid_dates:
        invalid_dates.append(date)
additional_invalid_dates = [datetime(2021, 9, 18), datetime(2021, 12, 11), datetime(2021, 12, 20), datetime(2022, 3, 5), datetime(2022, 3, 18), datetime(2022, 4, 8),
                           datetime(2022, 5, 2), datetime(2022, 5, 19), datetime(2022, 5, 24), datetime(2022, 9, 13), datetime(2022, 11, 16), datetime(2022, 11, 17), datetime(2022, 12, 16),
                           datetime(2022, 12, 18), datetime(2022, 12, 19), datetime(2023, 6, 1)]
invalid_dates += additional_invalid_dates

# Test period 1
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 6, 15)

# # Test period 2
# start_date = datetime(2021, 9, 1)
# end_date = datetime(2023, 6, 15)
write_goes_to_raster(GOES_500m_masked_data_path, GOES_500m_masked_output_dir, invalid_dates, start_date, end_date)

# %% [markdown]
# ## Write MODIS 500m interpolated data that is used as ground truth in the U-Net

# %%
modis_files = list(Path(MODIS_bsa_dir).iterdir())
os.makedirs(MODIS_interpolated_data_dir, exist_ok=True)

for mfile in modis_files:
    if mfile.is_file():
        modis_rxr = rxr.open_rasterio(mfile, masked=True)
        interpolated_values = fill_inputs_interpolate(modis_rxr) #interpolate_nan(modis_rxr)
        modis_rxr.values = interpolated_values
        output_file_name = os.path.join(MODIS_interpolated_data_dir, f"{mfile.name}")
        modis_rxr.rio.to_raster(output_file_name)
        # print(f"Wrote to {output_file_name}")
print(f"Execution complete!!!")

# %% [markdown]
# ## Calculate $R^2$ Scores for 500m GOES and 500m MODIS for Results

# %%
GOES_500m_raster_dir
MODIS_interpolated_data_dir

# %%
modis_files = list(Path(MODIS_interpolated_data_dir).iterdir())
# goes_500m_files = list(Path(GOES_500m_raster_dir).iterdir())
goes_500m_masked_files = list(Path(GOES_500m_masked_output_dir).iterdir())

modis_non_interpolated_files = list(Path(MODIS_bsa_dir).iterdir())

# %%
tif = modis_non_interpolated_files[10]
with rio.open(tif) as ds:
    arr = ds.read(1, masked=True)  # nodata -> mask
    extent = plotting_extent(ds)

plt.figure(figsize=(8,6))
im = plt.imshow(arr, extent=extent, origin="upper")
plt.tick_params(axis='x', rotation=45)
plt.title("Sentinel-2 Shortwave Albedo (keep-all)")
plt.xlabel(ds.crs.to_string()); plt.ylabel("y (map units)")
cbar = plt.colorbar(im, fraction=0.046, pad=0.04)
cbar.set_label("Albedo (0–1)")
plt.tight_layout(); plt.show()

# %%
goes_500m_masked_files2 = [p for p in goes_500m_masked_files if "2023" in p.name]
modis_non_interpolated_files2 = [p for p in modis_non_interpolated_files if "2023" in p.name]
modis_files2 = [p for p in modis_files if "2023" in p.name]
_ = calculate_r2_scores(goes_500m_masked_files2, modis_non_interpolated_files2)
# calculate_r2_scores(goes_500m_masked_files, modis_non_interpolated_files)#, modis_files)

# %%
# goes_500m_masked_files
# modis_non_interpolated_files
# modis_files

# %% [markdown]
# ## Visualize RMSE of U-Net

# %%
_ = calculate_RMSE_scores(goes_500m_masked_files2, modis_non_interpolated_files2)

# %%
# _ = plot_pixels_per_date(goes_500m_masked_files2, modis_non_interpolated_files2)

# %% [markdown]
# ## Visualize GOES U-Net 500m and MODIS 500m next to each other
# ### Visually compares daily GOES 500m albedo predictions to MODIS 500m interpolated albedo

# %%
# Load all files from the directories containing interpolated MODIS data and GOES 500m raster data
modis_files = list(Path(MODIS_interpolated_data_dir).iterdir())
goes_500m_files = list(Path(GOES_500m_masked_output_dir).iterdir())
# goes_500m_files = list(Path(GOES_500m_raster_dir).iterdir())

# Filter out only actual files (exclude subdirectories or non-file objects)
only_goes_files = [f for f in goes_500m_files if os.path.isfile(f)]

# Sort GOES files chronologically based on the date extracted from their filenames
sorted_goes_files = sorted(only_goes_files, key=lambda x: extract_date_from_goes_filename(x.name))

# Iterate through each sorted GOES file
for file in sorted_goes_files:
    if file.is_file():
        # Extract the GOES observation date from the filename
        goes_date = datetime.strptime("-".join(str(file.name).split("-")[0:3]), '%m-%d-%Y')
        
        # Open the GOES raster file using rioxarray
        goes_rxr = rxr.open_rasterio(file)
    
        # Match this GOES file with the corresponding MODIS file (same date in YYYYDDD format)
        for modis_file in modis_files:
            if modis_file.is_file() and goes_date.strftime('%Y%j') in str(modis_file.name):
                # Open the MODIS raster file
                modis_rxr = rxr.open_rasterio(modis_file)

                # Plot both GOES and MODIS raster data side by side
                fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 5))
                fig.subplots_adjust(hspace=0.4)  # Add vertical spacing between subplots

                # Plot GOES image
                goes_rxr.plot(ax=ax1)
                ax1.set_title(f"GOES 500m Albedo Data - {goes_date.strftime('%m-%d-%Y')}")
                ax1.set_xlabel("Meters west from Central Meridian")
                ax1.set_ylabel("Meters north from equator")

                # Plot MODIS image
                modis_rxr.plot(ax=ax2)
                ax2.set_title(f"MODIS 500m Albedo Data - {goes_date.strftime('%m-%d-%Y')}")
                ax2.set_xlabel("Meters west from Central Meridian")
                ax2.set_ylabel("Meters north from equator")

                # Automatically adjust layout to prevent overlap
                plt.tight_layout()
                plt.show()

# %% [markdown]
# ## Visualize GOES NaN Mask 500m and MODIS Ground Truth Data (non-masked)

# %%
# Load the list of MODIS blue sky albedo files and GOES 500m files with NaN values
modis_files = list(Path(MODIS_bsa_dir).iterdir())
goes_500m_files = list(Path(GOES_NaN_Data_dir).iterdir())

# Filter only actual files from the GOES list (exclude directories or other entities)
only_goes_files = [f for f in goes_500m_files if os.path.isfile(f)]

# Sort the GOES files based on extracted datetime from their filenames
sorted_goes_files = sorted(only_goes_files, key=lambda x: extract_date_from_goes_nan_filename(x.name))

# Iterate through each GOES file
for file in sorted_goes_files:
    if file.is_file():
        # Extract datetime from the GOES filename using a custom parser
        goes_date = extract_date_from_goes_nan_filename(file.name)

        # Open the GOES raster file using rioxarray
        goes_rxr = rxr.open_rasterio(file)
    
        # Loop through MODIS files to find the corresponding date match
        for modis_file in modis_files:
            if modis_file.is_file() and goes_date.strftime('%Y%j') in str(modis_file.name):
                # Open the corresponding MODIS raster file
                modis_rxr = rxr.open_rasterio(modis_file)

                # Create a side-by-side plot comparing GOES and MODIS data
                fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 5))
                fig.subplots_adjust(hspace=0.4)

                # Plot GOES data with title and axis labels
                goes_rxr.plot(ax=ax1)
                ax1.set_title(f"GOES 500m NaN Albedo Data - {goes_date.strftime('%m-%d-%Y')}")
                ax1.set_xlabel("Meters west from Central Meridian")
                ax1.set_ylabel("Meters north from Equator")

                # Plot MODIS data with title and axis labels
                modis_rxr.plot(ax=ax2)
                ax2.set_title(f"MODIS 500m Blue Sky Albedo Data - {goes_date.strftime('%m-%d-%Y')}")
                ax2.set_xlabel("Meters west from Central Meridian")
                ax2.set_ylabel("Meters north from Equator")

                # Improve layout and show the plot
                plt.tight_layout()
                plt.show()

# %% [markdown]
# ## Individual data visualizations

# %%
# Visualize GOES Raw Data Clipped
goes_rxr = rxr.open_rasterio(GOES_2km_ex_may_6_2023, masked=True)
goes_reprojected = goes_rxr.rio.reproject("EPSG:32613")
goes_clipped = goes_reprojected["LSA"].rio.clip(boundary_box_utm, all_touched=True,from_disk=True, drop=True).squeeze()

# Plot
plt.figure(figsize=(10, 4))
goes_clipped.plot()
plt.title("GOES-R 2km Albedo Data")
plt.xlabel("Meters west from Central Meridian")
plt.ylabel("Meters north from equator")
plt.style.use("default")
plt.show()

# %%
# Visualize MODIS Blue Sky Albedo
modis_rxr = rxr.open_rasterio(MODIS_bsa_ex_sep_1, masked=True)

# Plot
plt.figure(figsize=(10, 4))
modis_rxr.plot()
plt.title("MODIS Blue Sky Albedo Data")
plt.xlabel("Meters west from Central Meridian")
plt.ylabel("Meters north from equator")
plt.show()

# %% [markdown]
# # Plot MODIS BSA, WSA, blue-sky and GOES-R blue-sky

# %%
goes_file = Path("/bsuhome/tnde/scratch/felix/GOES/data/goes_output_data_new/OR_ABI-L2-LSAC-M6_G16_s20212441826171_e20212441828544_c20212441829544_clipped_reprojected_new.tif")
goes_file

# %%
goes_timestamp_str = extract_datetime_from_goes_filename(goes_file.name)
actual_date = datetime.strptime(goes_timestamp_str[:7], "%Y%j")
goes_display_hour = f"{goes_timestamp_str[7:9]}:{goes_timestamp_str[9:11]}"
goes_timestamp_str, actual_date, goes_display_hour

# %%
# import all the helper functions.
from modis_bluesky_albedo import *
black_sky_albedo_arr =  get_albedo_values(modis_albedo_data_dir, True) # Clear sky
white_sky_albedo_arr =  get_albedo_values(modis_albedo_data_dir, False) # Cloudy sky

# %%
# date_str = "2021-11-27"
# date_str = "2021-09-01"
date_str = "2023-06-05"
dt = datetime.strptime(date_str, "%Y-%m-%d")
yyyydoy = f"{dt.year}{dt.timetuple().tm_yday:03d}"

print(yyyydoy)

# %%
# modis_bsa = black_sky_albedo_arr["2021331"]
# modis_wsa = white_sky_albedo_arr["2021331"]
modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2021331_modis_blue_sky_albedo_.tif"

# goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/goes_output_data_new/OR_ABI-L2-LSAC-M6_G16_s20213311826176_e20213311828549_c20213311829572_clipped_reprojected_new.tif"
goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/156/18/OR_ABI-L2-LSAC-M6_G16_s20231561826179_e20231561828552_c20231561830350.nc"

# %%
# Visualize GOES Raw Data Clipped
goes_rxr = rxr.open_rasterio(goes_blue_sky, masked=True)
goes_reprojected = goes_rxr.rio.reproject("EPSG:32613")
goes_clipped = goes_reprojected["LSA"].rio.clip(boundary_box_utm, all_touched=True,from_disk=True, drop=True).squeeze()/10000

# Plot
plt.figure(figsize=(8, 6))
goes_clipped.plot()
plt.title("GOES-R 2km Albedo Data")
plt.xlabel("Easting")
plt.ylabel("Northing")
plt.style.use("default")
plt.show()

# %%
cf_file = "/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/tsi_cloud_fractions.csv"
cf_vals = pd.read_csv(cf_file)
print(len(cf_vals))
cf_vals = cf_vals[cf_vals["cf_interp"]<=0.10]
cf_vals = cf_vals.drop_duplicates(subset=["date"])
display(cf_vals.head())
len(cf_vals)

# %%
modis_test_path = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_*"
modis_test_files = os.path.abspath(modis_test_path)
modis_unet_test_files_list = sorted(glob.glob(modis_test_files))
modis_unet_test_files_list[:5]

# %% [markdown]
# ### U-Net actual vs downscaled images

# %%
# goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/012/18/OR_ABI-L2-LSAC-M6_G16_s20230121826172_e20230121828545_c20230121830487.nc"
goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/126/18/OR_ABI-L2-LSAC-M6_G16_s20231261826171_e20231261828544_c20231261830209.nc"
modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2021331_modis_blue_sky_albedo_.tif"
goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-01-12_modis_blue_sky_albedo_.tif"

# Visualize GOES Raw Data Clipped
goes_rxr = rxr.open_rasterio(goes_blue_sky, masked=True)
goes_reprojected = goes_rxr.rio.reproject("EPSG:32613")
goes_clipped = goes_reprojected["LSA"].rio.clip(boundary_box_utm, all_touched=True,from_disk=True, drop=True).squeeze()/10000

# Plot
plt.figure(figsize=(8, 6))
goes_clipped.plot()
plt.title("GOES-R 2km Albedo Data")
plt.xlabel("Easting")
plt.ylabel("Northing")
plt.style.use("default")
plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import rioxarray as rxr

# plt.style.use("default")

# goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/012/18/OR_ABI-L2-LSAC-M6_G16_s20230121826172_e20230121828545_c20230121830487.nc"
# modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2021331_modis_blue_sky_albedo_.tif"
# goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-01-12_modis_blue_sky_albedo_.tif"


goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/126/18/OR_ABI-L2-LSAC-M6_G16_s20231261826171_e20231261828544_c20231261830209.nc"
modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2023126_modis_blue_sky_albedo_.tif"
goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-05-06_modis_blue_sky_albedo_.tif"

# goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/156/18/OR_ABI-L2-LSAC-M6_G16_s20231561826179_e20231561828552_c20231561830350.nc"
# modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2023156_modis_blue_sky_albedo_.tif"
# goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-06-05_modis_blue_sky_albedo_.tif"

# -----------------------------
# GOES: reproject + clip + scale
# -----------------------------
goes_rxr = rxr.open_rasterio(goes_blue_sky, masked=True)
goes_reprojected = goes_rxr.rio.reproject("EPSG:32613")

# boundary_box_utm must be a geometry / GeoDataFrame in EPSG:32613
goes_clipped = (
    goes_reprojected["LSA"]
    .rio.clip(boundary_box_utm, all_touched=True, from_disk=True, drop=True)
    .squeeze()
)

scale_factor = 0.0001
goes_scaled = goes_clipped * scale_factor

# -----------------------------
# MODIS & predicted MODIS
# -----------------------------
modis_da = rxr.open_rasterio(modis_blue_sky, masked=True)
if "band" in modis_da.dims:
    modis_da = modis_da.sel(band=1, drop=True)

pred_da = rxr.open_rasterio(goes_blue_sky_predicted, masked=True)
if "band" in pred_da.dims:
    pred_da = pred_da.sel(band=1, drop=True)

# Optional physical clipping
def clip01(a):
    return a.clip(min=0.0, max=1.0)

goes_scaled = clip01(goes_scaled)
modis_da    = clip01(modis_da)
pred_da     = clip01(pred_da)

# -----------------------------
# Shared vmin/vmax across all three
# -----------------------------
vals_all = np.concatenate([
    goes_scaled.values[np.isfinite(goes_scaled.values)],
    modis_da.values[np.isfinite(modis_da.values)],
    pred_da.values[np.isfinite(pred_da.values)],
])

if vals_all.size > 0:
    vmin, vmax = np.nanpercentile(vals_all, [2, 98])
else:
    vmin, vmax = 0.0, 1.0

# -----------------------------
# Plot: three panels + one colorbar
# -----------------------------
fig, axes = plt.subplots(1, 3, figsize=(15, 4), constrained_layout=False)

# GOES
im0 = goes_scaled.plot.imshow(
    ax=axes[0],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[0].set_title("GOES LSAC Blue-sky Albedo")
axes[0].set_xlabel("Easting (m)")
axes[0].set_ylabel("Northing (m)")
axes[0].tick_params(axis="x", rotation=25)

# MODIS
im1 = modis_da.plot.imshow(
    ax=axes[1],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[1].set_title("MODIS Blue-sky Albedo")
axes[1].set_xlabel("Easting (m)")
axes[1].set_ylabel("Northing (m)")
axes[1].tick_params(axis="x", rotation=25)

# Predicted MODIS (U-Net)
im2 = pred_da.plot.imshow(
    ax=axes[2],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[2].set_title("U-Net Predicted GOES-R Blue-sky Albedo")
axes[2].set_xlabel("Easting (m)")
axes[2].set_ylabel("Northing (m)")
axes[2].tick_params(axis="x", rotation=25)

# Shared colorbar on the right
cax = fig.add_axes([0.92, 0.15, 0.015, 0.7])  # [left, bottom, width, height]
cbar = fig.colorbar(im2, cax=cax)
cbar.set_label("Blue-sky Albedo")

plt.subplots_adjust(right=0.9, wspace=0.25)
plt.show()

# %% [markdown]
# ## Visualize snow albedo field data

# %%
albedo_data = pd.read_csv(SAIL_field_data_file)
albedo_data['time'] = pd.to_datetime(albedo_data['time'])
albedo_data.set_index('time', inplace=True)

date = datetime(2023, 5, 6)
albedo_at_date = albedo_data.loc[date, '0']
print(albedo_at_date)

modis_500m_rxr = rxr.open_rasterio(MODIS_500m_05_06_23_file, masked=True)

# sail_location_lon_coord = -106.986
# sail_location_lat_cord = 38.956
sail_location_y_coord = 4313769.41
sail_location_x_coord = 327915.02

modis_data_at_location = modis_500m_rxr.sel(x=sail_location_x_coord, y=sail_location_y_coord, method="nearest").values
print(modis_data_at_location)

fig, ax2 = plt.subplots(1, figsize=(7,7))
modis_500m_rxr.plot()
plt.show()

# %%
# import re
# from pathlib import Path
# from datetime import datetime

# import numpy as np
# import pandas as pd
# import rioxarray as rxr
# import matplotlib.pyplot as plt
# from pyproj import Transformer

# -------------------------
# CONFIG
# -------------------------
S2_DIR = Path("/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/")   
SAIL_field_data_file = "/bsuhome/tnde/scratch/felix/Field-Albedo-Data/albedo_12MST_M1.csv"

# Your station location in projected coords (example you gave)
sail_location_y_coord = 4313769.41
sail_location_x_coord = 327915.02

# IMPORTANT: what CRS are those x/y coordinates in?
# Put your station CRS here (EPSG code). Example: UTM Zone 13N is EPSG:32613
STATION_CRS = "EPSG:32613"

# Field CSV columns
FIELD_TIME_COL = "time"
FIELD_VALUE_COL = "0"

# If needed, restrict S2 files with a pattern
S2_GLOB = "*_S2_*_hard.tif"   # or "*.tif" if you want everything

# -------------------------
# READ FIELD ALBEDO
# -------------------------
albedo_data = pd.read_csv(SAIL_field_data_file)

# If your CSV index is already the first column and has no header like your "head" print,
# you might need:
# albedo_data = pd.read_csv(SAIL_field_data_file, index_col=0)

albedo_data[FIELD_TIME_COL] = pd.to_datetime(albedo_data[FIELD_TIME_COL])
albedo_data = albedo_data.set_index(FIELD_TIME_COL).sort_index()

# Keep just the value series and ensure numeric
field_series = pd.to_numeric(albedo_data[FIELD_VALUE_COL], errors="coerce")

# -------------------------
# LOOP S2 FILES, EXTRACT PIXEL AT STATION
# -------------------------
date_re = re.compile(r"(\d{4}-\d{2}-\d{2})")  # grabs YYYY-MM-DD from filename
rows = []

for fp in sorted(S2_DIR.glob(S2_GLOB)):
    m = date_re.search(fp.name)
    if not m:
        continue

    s2_date = pd.to_datetime(m.group(1)).normalize()

    # open S2 raster
    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    # Transform station coords (STATION_CRS) -> raster CRS (if different)
    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"Raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    # sample nearest pixel
    s2_val = da.sel(x=x_q, y=y_q, method="nearest").values

    # convert numpy masked/array -> float
    if isinstance(s2_val, np.ndarray):
        s2_val = s2_val.item() if s2_val.size == 1 else np.nan

    # pull matching field value (same date)
    field_val = field_series.get(s2_date, np.nan)

    rows.append(
        {
            "date": s2_date,
            "s2_albedo": float(s2_val) if pd.notna(s2_val) else np.nan,
            "field_albedo": float(field_val) if pd.notna(field_val) else np.nan,
            "file": fp.name,
        }
    )

match_df = pd.DataFrame(rows).dropna(subset=["s2_albedo", "field_albedo"]).sort_values("date")

print(f"Matched days: {len(match_df)}")
print(match_df.head())

# -------------------------
# PLOT LINE COMPARISON
# -------------------------
plt.figure(figsize=(14, 5))
plt.plot(match_df["date"], match_df["s2_albedo"], marker="o", label="Sentinel-2")
plt.plot(match_df["date"], match_df["field_albedo"], marker="o", label="Field pyranometer")
plt.xlabel("Date")
plt.ylabel("Albedo")
# plt.title("Sentinel-2 vs Field Albedo at Station")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# -------------------------
# CONFIG
# -------------------------
S2_DIR = Path("/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/")   
SAIL_field_data_file = "/bsuhome/tnde/scratch/felix/Field-Albedo-Data/albedo_12MST_M1.csv"

# Your station location in projected coords (example you gave)
sail_location_y_coord = 4313769.41
sail_location_x_coord = 327915.02

# IMPORTANT: what CRS are those x/y coordinates in?
# Put your station CRS here (EPSG code). Example: UTM Zone 13N is EPSG:32613
STATION_CRS = "EPSG:32613"

# Field CSV columns
FIELD_TIME_COL = "time"
FIELD_VALUE_COL = "0"

# If needed, restrict S2 files with a pattern
S2_GLOB = "*_S2_*_hard.tif"   # or "*.tif" if you want everything

# -------------------------
# READ FIELD ALBEDO
# -------------------------
albedo_data = pd.read_csv(SAIL_field_data_file)

# If your CSV index is already the first column and has no header like your "head" print,
# you might need:
# albedo_data = pd.read_csv(SAIL_field_data_file, index_col=0)

albedo_data[FIELD_TIME_COL] = pd.to_datetime(albedo_data[FIELD_TIME_COL])
albedo_data = albedo_data.set_index(FIELD_TIME_COL).sort_index()

# Keep just the value series and ensure numeric
field_series = pd.to_numeric(albedo_data[FIELD_VALUE_COL], errors="coerce")

# ------------------------------------------
# LOOP S2 FILES, EXTRACT PIXEL AT STATION
# ------------------------------------------
date_re = re.compile(r"(\d{4}-\d{2}-\d{2})")  # grabs YYYY-MM-DD from filename
rows = []

for fp in sorted(S2_DIR.glob(S2_GLOB)):
    m = date_re.search(fp.name)
    if not m:
        continue

    s2_date = pd.to_datetime(m.group(1)).normalize()

    # open S2 raster
    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    # Transform station coords (STATION_CRS) -> raster CRS (if different)
    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"Raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    # --- sample average of 6 nearest neighbors ---
    # find nearest pixel center indices
    ix = int(np.abs(da["x"].values - x_q).argmin())
    iy = int(np.abs(da["y"].values - y_q).argmin())

    # build candidate window around the nearest pixel (3x3 = 9 candidates)
    x_vals = da["x"].values
    y_vals = da["y"].values
    nx = x_vals.size
    ny = y_vals.size

    x0 = max(ix - 1, 0)
    x1 = min(ix + 2, nx)   # +2 because slice end is exclusive
    y0 = max(iy - 1, 0)
    y1 = min(iy + 2, ny)

    win = da.isel(x=slice(x0, x1), y=slice(y0, y1))

    # compute distances from query point to each candidate pixel center
    xx, yy = np.meshgrid(win["x"].values, win["y"].values)
    dist2 = (xx - x_q) ** 2 + (yy - y_q) ** 2

    # take the 6 closest candidates, average their (non-NaN) values
    vals = win.values.reshape(-1)
    dflat = dist2.reshape(-1)

    valid = np.isfinite(vals) & np.isfinite(dflat)
    vals = vals[valid]
    dflat = dflat[valid]

    if vals.size == 0:
        s2_val = np.nan
    else:
        k = min(6, vals.size)
        idx = np.argpartition(dflat, k - 1)[:k]
        s2_val = float(np.nanmean(vals[idx]))

    # convert numpy masked/array -> float
    if isinstance(s2_val, np.ndarray):
        s2_val = s2_val.item() if s2_val.size == 1 else np.nan

    # pull matching field value (same date)
    field_val = field_series.get(s2_date, np.nan)

    rows.append(
        {
            "date": s2_date,
            "s2_albedo": float(s2_val) if pd.notna(s2_val) else np.nan,
            "field_albedo": float(field_val) if pd.notna(field_val) else np.nan,
            "file": fp.name,
        }
    )

match_df = pd.DataFrame(rows).dropna(subset=["s2_albedo", "field_albedo"]).sort_values("date")

print(f"Matched days: {len(match_df)}")
print(match_df.head())

# -------------------------
# PLOT LINE COMPARISON
# -------------------------
plt.figure(figsize=(14, 5))
plt.plot(match_df["date"], match_df["s2_albedo"], marker="o", label="Sentinel-2")
plt.plot(match_df["date"], match_df["field_albedo"], marker="o", label="Field pyranometer")
plt.xlabel("Date")
plt.ylabel("Albedo")
# plt.title("Sentinel-2 vs Field Albedo at Station")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
match_df[match_df["field_albedo"] < 0.15]

# %%
# -------------------------
# CONFIG
# -------------------------
S2_DIR = Path("/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/")   
SAIL_field_data_file = "/bsuhome/tnde/scratch/felix/Field-Albedo-Data/albedo_12MST_M1.csv"

sail_location_y_coord = 4313769.41
sail_location_x_coord = 327915.02
STATION_CRS = "EPSG:32613"

FIELD_TIME_COL = "time"
FIELD_VALUE_COL = "0"
S2_GLOB = "*_S2_*_soft.tif"

# -------------------------
# READ FIELD ALBEDO
# -------------------------
albedo_data = pd.read_csv(SAIL_field_data_file)
albedo_data[FIELD_TIME_COL] = pd.to_datetime(albedo_data[FIELD_TIME_COL])
albedo_data = albedo_data.set_index(FIELD_TIME_COL).sort_index()

# numeric series + normalize index to dates (midnight)
field_series = pd.to_numeric(albedo_data[FIELD_VALUE_COL], errors="coerce")
field_series.index = field_series.index.normalize()

# -------------------------
# LOOP S2 FILES, EXTRACT PIXEL AT STATION
# -------------------------
date_re = re.compile(r"(\d{4}-\d{2}-\d{2})")
rows = []

for fp in sorted(S2_DIR.glob(S2_GLOB)):
    m = date_re.search(fp.name)
    if not m:
        continue

    s2_date = pd.to_datetime(m.group(1)).normalize()

    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"Raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    s2_val = da.sel(x=x_q, y=y_q, method="nearest").values
    if isinstance(s2_val, np.ndarray):
        s2_val = s2_val.item() if s2_val.size == 1 else np.nan

    field_val = field_series.get(s2_date, np.nan)

    rows.append(
        {
            "date": s2_date,
            "s2_albedo": float(s2_val) if pd.notna(s2_val) else np.nan,
            "field_albedo": float(field_val) if pd.notna(field_val) else np.nan,
            "file": fp.name,
        }
    )

match_df = (
    pd.DataFrame(rows)
    .dropna(subset=["s2_albedo", "field_albedo"])
    .sort_values("date")
)

# -------------------------
# FILTER OUT 0/1 ALBEDO + DROP DUPLICATE DATES
# -------------------------
# remove any row where either series is exactly 0 or 1
match_df = match_df[
    (~match_df["s2_albedo"].isin([0.0])) &
    (~match_df["field_albedo"].isin([0.0]))
]

# match_df = match_df[
#     (~match_df["s2_albedo"].isin([0.0, 1.0])) &
#     (~match_df["field_albedo"].isin([0.0, 1.0]))
# ]


# keep only one row per date (keeps the first occurrence after sorting)
match_df = match_df.drop_duplicates(subset=["date"], keep="first").sort_values("date")

print(f"Matched days (filtered, deduped): {len(match_df)}")
print(match_df.head())

# -------------------------
# PLOT LINE COMPARISON
# -------------------------
plt.figure(figsize=(14, 5))
plt.plot(match_df["date"], match_df["s2_albedo"], marker="o", label="Sentinel-2")
plt.plot(match_df["date"], match_df["field_albedo"], marker="o", label="Field pyranometer")
plt.xlabel("Date")
plt.ylabel("Albedo")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# -------------------------
# CONFIG
# -------------------------
S2_DIR = Path("/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/")   
SAIL_field_data_file = "/bsuhome/tnde/scratch/felix/Field-Albedo-Data/albedo_12MST_M1.csv"
MODIS_DIR = Path("/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/")


sail_location_y_coord = 4313769.41
sail_location_x_coord = 327915.02
STATION_CRS = "EPSG:32613"

FIELD_TIME_COL = "time"
FIELD_VALUE_COL = "0"
S2_GLOB = "*_S2_*_soft.tif"

# -------------------------
# READ FIELD ALBEDO
# -------------------------
albedo_data = pd.read_csv(SAIL_field_data_file)
albedo_data[FIELD_TIME_COL] = pd.to_datetime(albedo_data[FIELD_TIME_COL])
albedo_data = albedo_data.set_index(FIELD_TIME_COL).sort_index()

# numeric series + normalize index to dates (midnight)
field_series = pd.to_numeric(albedo_data[FIELD_VALUE_COL], errors="coerce")
field_series.index = field_series.index.normalize()

# -------------------------
# LOOP S2 FILES, EXTRACT PIXEL AT STATION
# -------------------------
date_re = re.compile(r"(\d{4}-\d{2}-\d{2})")
rows = []

for fp in sorted(S2_DIR.glob(S2_GLOB)):
    m = date_re.search(fp.name)
    if not m:
        continue

    s2_date = pd.to_datetime(m.group(1)).normalize()

    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"Raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    s2_val = da.sel(x=x_q, y=y_q, method="nearest").values
    if isinstance(s2_val, np.ndarray):
        s2_val = s2_val.item() if s2_val.size == 1 else np.nan

    field_val = field_series.get(s2_date, np.nan)

    rows.append(
        {
            "date": s2_date,
            "s2_albedo": float(s2_val) if pd.notna(s2_val) else np.nan,
            "field_albedo": float(field_val) if pd.notna(field_val) else np.nan,
            "file": fp.name,
        }
    )

match_df = (
    pd.DataFrame(rows)
    .dropna(subset=["s2_albedo", "field_albedo"])
    .sort_values("date")
)

# -------------------------
# FILTER OUT 0/1 ALBEDO + DROP DUPLICATE DATES
# -------------------------
# remove any row where either series is exactly 0 or 1
match_df = match_df[
    (~match_df["s2_albedo"].isin([0.0])) &
    (~match_df["field_albedo"].isin([0.0]))
]

# match_df = match_df[
#     (~match_df["s2_albedo"].isin([0.0, 1.0])) &
#     (~match_df["field_albedo"].isin([0.0, 1.0]))
# ]


# keep only one row per date (keeps the first occurrence after sorting)
match_df = match_df.drop_duplicates(subset=["date"], keep="first").sort_values("date")

print(f"Matched days (filtered, deduped): {len(match_df)}")
print(match_df.head())

# -------------------------
# PLOT LINE COMPARISON
# -------------------------
plt.figure(figsize=(14, 5))
plt.plot(match_df["date"], match_df["s2_albedo"], marker="o", label="Sentinel-2")
plt.plot(match_df["date"], match_df["field_albedo"], marker="o", label="Field pyranometer")
plt.xlabel("Date")
plt.ylabel("Albedo")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# -------------------------
# CONFIG
# -------------------------
S2_DIR = Path("/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/")   
SAIL_field_data_file = "/bsuhome/tnde/scratch/felix/Field-Albedo-Data/albedo_12MST_M1.csv"
MODIS_DIR = Path("/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/")

sail_location_y_coord = 4313769.41
sail_location_x_coord = 327915.02
STATION_CRS = "EPSG:32613"

FIELD_TIME_COL = "time"
FIELD_VALUE_COL = "0"
S2_GLOB = "*_S2_*_soft.tif"
MODIS_GLOB = "*_modis_blue_sky_albedo_*.tif"

# -------------------------
# READ FIELD ALBEDO
# -------------------------
albedo_data = pd.read_csv(SAIL_field_data_file)
albedo_data[FIELD_TIME_COL] = pd.to_datetime(albedo_data[FIELD_TIME_COL])
albedo_data = albedo_data.set_index(FIELD_TIME_COL).sort_index()

field_series = pd.to_numeric(albedo_data[FIELD_VALUE_COL], errors="coerce")
field_series.index = field_series.index.normalize()

# -------------------------
# LOOP S2 FILES, EXTRACT PIXEL AT STATION
# -------------------------
date_re = re.compile(r"(\d{4}-\d{2}-\d{2})")
rows = []

for fp in sorted(S2_DIR.glob(S2_GLOB)):
    m = date_re.search(fp.name)
    if not m:
        continue

    s2_date = pd.to_datetime(m.group(1)).normalize()

    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"Raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    s2_val = da.sel(x=x_q, y=y_q, method="nearest").values
    if isinstance(s2_val, np.ndarray):
        s2_val = s2_val.item() if s2_val.size == 1 else np.nan

    field_val = field_series.get(s2_date, np.nan)

    rows.append(
        {
            "date": s2_date,
            "s2_albedo": float(s2_val) if pd.notna(s2_val) else np.nan,
            "field_albedo": float(field_val) if pd.notna(field_val) else np.nan,
            "file": fp.name,
        }
    )

match_df = (
    pd.DataFrame(rows)
    .dropna(subset=["s2_albedo", "field_albedo"])
    .sort_values("date")
)

# -------------------------
# ADD MODIS: extract date from YYYYDOY prefix and sample nearest pixel
# -------------------------
modis_re = re.compile(r"^(\d{7})_modis_blue_sky_albedo_.*\.tif$")  # YYYYDOY

modis_rows = []
for fp in sorted(MODIS_DIR.glob(MODIS_GLOB)):
    m = modis_re.match(fp.name)
    if not m:
        continue

    yyyydoy = m.group(1)                 # e.g., "2021246"
    modis_date = pd.to_datetime(yyyydoy, format="%Y%j").normalize()

    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"MODIS raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    modis_val = da.sel(x=x_q, y=y_q, method="nearest").values
    if isinstance(modis_val, np.ndarray):
        modis_val = modis_val.item() if modis_val.size == 1 else np.nan

    modis_rows.append({"date": modis_date, "modis_albedo": float(modis_val) if pd.notna(modis_val) else np.nan})

modis_df = pd.DataFrame(modis_rows).dropna(subset=["modis_albedo"]).sort_values("date")
modis_df = modis_df.drop_duplicates(subset=["date"], keep="first")

# Merge MODIS onto the matched S2/field dates (keeps your existing matched dates)
match_df = match_df.merge(modis_df, on="date", how="left")

# -------------------------
# FILTER OUT 0 ALBEDO + DROP DUPLICATE DATES
# -------------------------
match_df = match_df[
    (~match_df["s2_albedo"].isin([0.0])) &
    (~match_df["field_albedo"].isin([0.0]))
].drop_duplicates(subset=["date"], keep="first").sort_values("date")

print(f"Matched days (filtered, deduped): {len(match_df)}")
print(match_df.head())

# -------------------------
# PLOT LINE COMPARISON
# -------------------------
plt.figure(figsize=(14, 5))
plt.plot(match_df["date"], match_df["s2_albedo"], marker="o", label="Sentinel-2")
plt.plot(match_df["date"], match_df["field_albedo"], marker="o", label="Field pyranometer")

# MODIS (only plot where available)
plt.plot(match_df["date"], match_df["modis_albedo"], marker="o", label="MODIS blue-sky", alpha=0.9)

plt.xlabel("Date")
plt.ylabel("Albedo")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# -------------------------
# CONFIG
# -------------------------
S2_DIR = Path("/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/")   
SAIL_field_data_file = "/bsuhome/tnde/scratch/felix/Field-Albedo-Data/albedo_12MST_M1.csv"
MODIS_DIR = Path("/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/")
Downscaled_MODIS_DIR = Path("/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/")

sail_location_y_coord = 4313769.41
sail_location_x_coord = 327915.02
STATION_CRS = "EPSG:32613"

FIELD_TIME_COL = "time"
FIELD_VALUE_COL = "0"
S2_GLOB = "*_S2_*_soft.tif"
MODIS_GLOB = "*_modis_blue_sky_albedo_*.tif"
DOWNSCALED_MODIS_GLOB = "predicted_*_modis_blue_sky_albedo_*.tif"

# -------------------------
# READ FIELD ALBEDO
# -------------------------
albedo_data = pd.read_csv(SAIL_field_data_file)
albedo_data[FIELD_TIME_COL] = pd.to_datetime(albedo_data[FIELD_TIME_COL])
albedo_data = albedo_data.set_index(FIELD_TIME_COL).sort_index()

field_series = pd.to_numeric(albedo_data[FIELD_VALUE_COL], errors="coerce")
field_series.index = field_series.index.normalize()

# -------------------------
# LOOP S2 FILES, EXTRACT PIXEL AT STATION
# -------------------------
date_re = re.compile(r"(\d{4}-\d{2}-\d{2})")
rows = []

for fp in sorted(S2_DIR.glob(S2_GLOB)):
    m = date_re.search(fp.name)
    if not m:
        continue

    s2_date = pd.to_datetime(m.group(1)).normalize()

    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"Raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    s2_val = da.sel(x=x_q, y=y_q, method="nearest").values
    if isinstance(s2_val, np.ndarray):
        s2_val = s2_val.item() if s2_val.size == 1 else np.nan

    field_val = field_series.get(s2_date, np.nan)

    rows.append(
        {
            "date": s2_date,
            "s2_albedo": float(s2_val) if pd.notna(s2_val) else np.nan,
            "field_albedo": float(field_val) if pd.notna(field_val) else np.nan,
            "file": fp.name,
        }
    )

match_df = (
    pd.DataFrame(rows)
    .dropna(subset=["s2_albedo", "field_albedo"])
    .sort_values("date")
)

# -------------------------
# ADD MODIS: extract date from YYYYDOY prefix and sample nearest pixel
# -------------------------
modis_re = re.compile(r"^(\d{7})_modis_blue_sky_albedo_.*\.tif$")  # YYYYDOY

modis_rows = []
for fp in sorted(MODIS_DIR.glob(MODIS_GLOB)):
    m = modis_re.match(fp.name)
    if not m:
        continue

    yyyydoy = m.group(1)  # e.g., "2021246"
    modis_date = pd.to_datetime(yyyydoy, format="%Y%j").normalize()

    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"MODIS raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    modis_val = da.sel(x=x_q, y=y_q, method="nearest").values
    if isinstance(modis_val, np.ndarray):
        modis_val = modis_val.item() if modis_val.size == 1 else np.nan

    modis_rows.append(
        {"date": modis_date, "modis_albedo": float(modis_val) if pd.notna(modis_val) else np.nan}
    )

modis_df = pd.DataFrame(modis_rows).dropna(subset=["modis_albedo"]).sort_values("date")
modis_df = modis_df.drop_duplicates(subset=["date"], keep="first")
match_df = match_df.merge(modis_df, on="date", how="left")

# -------------------------
# ADD DOWNSCALED MODIS: extract date from predicted_YYYYDOY_... and sample nearest pixel
# -------------------------
down_modis_re = re.compile(r"^predicted_(\d{7})_modis_blue_sky_albedo_.*\.tif$")  # predicted_YYYYDOY...

down_rows = []
for fp in sorted(Downscaled_MODIS_DIR.glob(DOWNSCALED_MODIS_GLOB)):
    m = down_modis_re.match(fp.name)
    if not m:
        continue

    yyyydoy = m.group(1)  # e.g., "2021253"
    down_date = pd.to_datetime(yyyydoy, format="%Y%j").normalize()

    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    raster_crs = da.rio.crs
    x_q, y_q = sail_location_x_coord, sail_location_y_coord

    if raster_crs is None:
        raise ValueError(f"Downscaled MODIS raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    down_val = da.sel(x=x_q, y=y_q, method="nearest").values
    if isinstance(down_val, np.ndarray):
        down_val = down_val.item() if down_val.size == 1 else np.nan

    down_rows.append(
        {"date": down_date, "downscaled_modis_albedo": float(down_val) if pd.notna(down_val) else np.nan}
    )

down_df = pd.DataFrame(down_rows).dropna(subset=["downscaled_modis_albedo"]).sort_values("date")
down_df = down_df.drop_duplicates(subset=["date"], keep="first")
match_df = match_df.merge(down_df, on="date", how="left")

# -------------------------
# FILTER OUT 0 ALBEDO + DROP DUPLICATE DATES
# -------------------------
match_df = match_df[
    (~match_df["s2_albedo"].isin([0.0])) &
    (~match_df["field_albedo"].isin([0.0]))
].drop_duplicates(subset=["date"], keep="first").sort_values("date")

print(f"Matched days (filtered, deduped): {len(match_df)}")
print(match_df.head())

# -------------------------
# PLOT LINE COMPARISON
# -------------------------
plt.figure(figsize=(14, 5))
plt.plot(match_df["date"], match_df["s2_albedo"], marker="o", label="Sentinel-2")
plt.plot(match_df["date"], match_df["field_albedo"], marker="o", label="Field pyranometer")
plt.plot(match_df["date"], match_df["modis_albedo"], marker="o", label="MODIS blue-sky", alpha=0.9)
plt.plot(match_df["date"], match_df["downscaled_modis_albedo"], marker="o", label="Downscaled MODIS", alpha=0.9)

plt.xlabel("Date")
plt.ylabel("Albedo")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# -------------------------
# CORRELATION PLOT OF ALL SERIES
# -------------------------

corr_cols = [
    "s2_albedo",
    "field_albedo",
    "modis_albedo",
    "downscaled_modis_albedo"
]

corr_labels = [
    "Sentinel-2",
    "Field pyranometer",
    "MODIS blue-sky",
    "Downscaled MODIS"
]

# Keep only available columns
corr_cols_existing = [c for c in corr_cols if c in match_df.columns]
corr_labels_existing = [
    corr_labels[corr_cols.index(c)] for c in corr_cols_existing
]

# Compute Pearson correlation
corr_matrix = match_df[corr_cols_existing].corr(method="pearson")

# Rename rows/columns for cleaner plot labels
corr_matrix.index = corr_labels_existing
corr_matrix.columns = corr_labels_existing

# Plot correlation heatmap
fig, ax = plt.subplots(figsize=(8, 6))

im = ax.imshow(
    corr_matrix,
    vmin=-1,
    vmax=1,
    cmap="GnBu"
)

# Axis labels
ax.set_xticks(np.arange(len(corr_matrix.columns)))
ax.set_yticks(np.arange(len(corr_matrix.index)))

ax.set_xticklabels(corr_matrix.columns, rotation=35, ha="right", fontsize=15)
ax.set_yticklabels(corr_matrix.index, rotation=35, fontsize=15)

# Add correlation values inside cells
for i in range(len(corr_matrix.index)):
    for j in range(len(corr_matrix.columns)):
        value = corr_matrix.iloc[i, j]
        ax.text(
            j,
            i,
            f"{value:.2f}",
            ha="center",
            va="center",
            color="black",
            fontsize=18
        )

# Colorbar
cbar = fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cbar.set_label("Pearson correlation coefficient", fontsize=15)

# ax.set_title("Correlation Plot of Albedo Time Series", fontsize=18)

plt.tight_layout()
plt.show()

# %%
cf_file = "/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/tsi_cloud_fractions.csv"
cf_vals = pd.read_csv(cf_file)
print(len(cf_vals))
cf_vals = cf_vals[cf_vals["cf_interp"]<=0.40]
cf_vals = cf_vals.drop_duplicates(subset=["date"])
display(cf_vals.head())
len(cf_vals)

# %%
albedo_path = "/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/*_S2_BLUE20m_SW_hard.tif"
albedo_files = os.path.abspath(albedo_path)
albedo_files_sorted = sorted(glob.glob(albedo_files))
unet_files_list = []
# invalid_dates = ["2021-09-23", "2022-03-12", "2022-03-12", 
#                  "2022-04-06", "2022-05-06", "2022-05-26", 
#                  "2022-09-18", "2022-10-13", "2022-10-18"]

# invalid_dates = ["2022-07-10", "2022-05-06", "2022-04-21", 
#                  "2022-04-06", "2022-04-01", "2022-03-12", 
#                  "2021-09-23"]

invalid_dates = ["2022-09-23", "2021-10-28", "2022-03-12", "2022-04-01", 
                 "2022-04-06", "2022-04-21", "2022-04-26", "2022-05-06", 
                 "2022-05-26", "2022-05-31", "2022-07-10"]

for s2_date in list(cf_vals["date"]):
    unet_file = f"/bsuhome/tnde/scratch/felix/Sentinel-2/s2_albedo_outputs/{s2_date}_S2_BLUE20m_SW_hard.tif"
    if s2_date in invalid_dates:
        pass
    elif unet_file not in albedo_files_sorted:
        print(f"File: {unet_file} not found in list.")
    else:
        unet_files_list.append(unet_file)
print(f"Number of U-Net files: {len(unet_files_list)}")

# %%
unet_files_list

# %%
albedo_data

# %%
# -------------------------
# CONFIG
# -------------------------
SAIL_field_data_file = "/bsuhome/tnde/scratch/felix/Field-Albedo-Data/albedo_12MST_M1.csv"

# station location (your example projected coords)
sail_location_y_coord = 4313769.41
sail_location_x_coord = 327915.02

# CRS of the station x/y coordinates (set correctly!)
STATION_CRS = "EPSG:32613"

FIELD_TIME_COL = "time"
FIELD_VALUE_COL = "0"

# -------------------------
# 1) READ FIELD ALBEDO
# -------------------------
albedo_data = pd.read_csv(SAIL_field_data_file)
albedo_data[FIELD_TIME_COL] = pd.to_datetime(albedo_data[FIELD_TIME_COL])
albedo_data = albedo_data.set_index(FIELD_TIME_COL).sort_index()

field_series = pd.to_numeric(albedo_data[FIELD_VALUE_COL], errors="coerce")

# -------------------------
# 2) LOOP S2 FILES FROM YOUR LIST
# -------------------------
date_re = re.compile(r"(\d{4}-\d{2}-\d{2})")
rows = []

for fp in unet_files_list:
    fp = Path(fp)

    m = date_re.search(fp.name)
    if not m:
        # skip files that don't contain YYYY-MM-DD in their name
        continue

    s2_date = pd.to_datetime(m.group(1)).normalize()

    da = rxr.open_rasterio(fp, masked=True).squeeze("band", drop=True)

    raster_crs = da.rio.crs
    if raster_crs is None:
        raise ValueError(f"Raster has no CRS: {fp.name}. Add/write CRS before sampling.")

    # station coords -> raster coords (if needed)
    x_q, y_q = sail_location_x_coord, sail_location_y_coord
    if str(raster_crs) != STATION_CRS:
        transformer = Transformer.from_crs(STATION_CRS, raster_crs, always_xy=True)
        x_q, y_q = transformer.transform(sail_location_x_coord, sail_location_y_coord)

    # sample nearest pixel at station
    s2_val = da.sel(x=x_q, y=y_q, method="nearest").values
    if isinstance(s2_val, np.ndarray):
        s2_val = s2_val.item() if s2_val.size == 1 else np.nan

    # same-day field match
    field_val = field_series.get(s2_date, np.nan)

    rows.append(
        {
            "date": s2_date,
            "s2_albedo": float(s2_val) if pd.notna(s2_val) else np.nan,
            "field_albedo": float(field_val) if pd.notna(field_val) else np.nan,
            "file": fp.name,
        }
    )

match_df = (
    pd.DataFrame(rows)
    .dropna(subset=["s2_albedo", "field_albedo"])
    .sort_values("date")
)

print(f"Matched days: {len(match_df)}")
print(match_df.head())

# -------------------------
# 3) PLOT LINE COMPARISON
# -------------------------
plt.figure(figsize=(10, 5))
plt.plot(match_df["date"], match_df["s2_albedo"], marker="o", label="Sentinel-2 (pixel @ station)")
plt.plot(match_df["date"], match_df["field_albedo"], marker="o", label="Field pyranometer")
plt.xlabel("Date")
plt.ylabel("Albedo")
plt.title("Sentinel-2 vs Field Albedo at Station")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# https://ieeexplore.ieee.org/xpl/RecentIssue.jsp?punumber=36

# %%
goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2021/331/18/OR_ABI-L2-LSAC-M6_G16_s20213311826176_e20213311828549_c20213311829572.nc"
modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2021331_modis_blue_sky_albedo_.tif"
goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-05-06_modis_blue_sky_albedo_.tif"

# -----------------------------
# GOES: reproject + clip + scale
# -----------------------------
goes_rxr = rxr.open_rasterio(goes_blue_sky, masked=True)
# goes_reprojected = goes_rxr.rio.reproject("EPSG:32613")
goes_reprojected = goes_rxr.rio.reproject("EPSG:32613")

# boundary_box_utm must be a geometry / GeoDataFrame in EPSG:32613
goes_clipped = (
    goes_reprojected["LSA"]
    .rio.clip(boundary_box_utm, all_touched=True, from_disk=True, drop=True)
    .squeeze()
)

scale_factor = 0.0001
goes_scaled = goes_clipped * scale_factor

# -----------------------------
# MODIS & predicted MODIS
# -----------------------------
modis_da = rxr.open_rasterio(modis_blue_sky, masked=True)
if "band" in modis_da.dims:
    modis_da = modis_da.sel(band=1, drop=True)

pred_da = rxr.open_rasterio(goes_blue_sky_predicted, masked=True)
if "band" in pred_da.dims:
    pred_da = pred_da.sel(band=1, drop=True)

# Optional physical clipping
def clip01(a):
    return a.clip(min=0.0, max=1.0)

goes_scaled = clip01(goes_scaled)
modis_da    = clip01(modis_da)
pred_da     = clip01(pred_da)

# -----------------------------
# Shared vmin/vmax across all three
# -----------------------------
vals_all = np.concatenate([
    goes_scaled.values[np.isfinite(goes_scaled.values)],
    modis_da.values[np.isfinite(modis_da.values)],
    pred_da.values[np.isfinite(pred_da.values)],
])

if vals_all.size > 0:
    vmin, vmax = np.nanpercentile(vals_all, [2, 98])
else:
    vmin, vmax = 0.0, 1.0

# -----------------------------
# Plot: three panels + one colorbar
# -----------------------------
fig, axes = plt.subplots(1, 2, figsize=(15, 6), constrained_layout=False)

# GOES
im0 = goes_scaled.plot.imshow(
    ax=axes[0],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[0].set_title("GOES-R LSAC 2km Blue-sky Albedo")
axes[0].set_xlabel("Easting (m)")
axes[0].set_ylabel("Northing (m)")
axes[0].tick_params(axis="x", rotation=25)

# MODIS
im1 = modis_da.plot.imshow(
    ax=axes[1],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[1].set_title("MODIS 500m Blue-sky Albedo")
axes[1].set_xlabel("Easting (m)")
axes[1].set_ylabel("Northing (m)")
axes[1].tick_params(axis="x", rotation=25)

# Shared colorbar on the right
cax = fig.add_axes([0.92, 0.15, 0.015, 0.7])  # [left, bottom, width, height]
cbar = fig.colorbar(im1, cax=cax)
cbar.set_label("Blue-sky Albedo")

plt.subplots_adjust(right=0.9, wspace=0.25)
plt.show()

# %%
# # import numpy as np
# # import matplotlib.pyplot as plt
# # import rioxarray as rxr

# goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2021/331/18/OR_ABI-L2-LSAC-M6_G16_s20213311826176_e20213311828549_c20213311829572.nc"
# modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2021331_modis_blue_sky_albedo_.tif"
# goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-05-06_modis_blue_sky_albedo_.tif"

# # -----------------------------------
# # Convert boundary to lon/lat first
# # -----------------------------------
# boundary_box_ll = boundary_box_utm.to_crs("EPSG:4326")

# # -----------------------------
# # GOES: reproject + clip + scale
# # -----------------------------
# goes_rxr = rxr.open_rasterio(goes_blue_sky, masked=True)

# # Reproject GOES to lon/lat
# goes_reprojected = goes_rxr.rio.reproject("EPSG:4326")

# goes_clipped = (
#     goes_reprojected["LSA"]
#     .rio.clip(boundary_box_ll.geometry, all_touched=True, from_disk=True, drop=True)
#     .squeeze()
# )

# scale_factor = 0.0001
# goes_scaled = goes_clipped * scale_factor

# # -----------------------------
# # MODIS & predicted MODIS
# # Reproject both to lon/lat
# # -----------------------------
# modis_da = rxr.open_rasterio(modis_blue_sky, masked=True)
# if "band" in modis_da.dims:
#     modis_da = modis_da.sel(band=1, drop=True)
# modis_da = modis_da.rio.reproject("EPSG:4326")
# modis_da = modis_da.rio.clip(boundary_box_ll.geometry, all_touched=True, from_disk=True, drop=True)

# pred_da = rxr.open_rasterio(goes_blue_sky_predicted, masked=True)
# if "band" in pred_da.dims:
#     pred_da = pred_da.sel(band=1, drop=True)
# pred_da = pred_da.rio.reproject("EPSG:4326")
# pred_da = pred_da.rio.clip(boundary_box_ll.geometry, all_touched=True, from_disk=True, drop=True)

# # Optional physical clipping
# def clip01(a):
#     return a.clip(min=0.0, max=1.0)

# goes_scaled = clip01(goes_scaled)
# modis_da    = clip01(modis_da)
# pred_da     = clip01(pred_da)

# # -----------------------------
# # Shared vmin/vmax across all three
# # -----------------------------
# vals_all = np.concatenate([
#     goes_scaled.values[np.isfinite(goes_scaled.values)],
#     modis_da.values[np.isfinite(modis_da.values)],
#     pred_da.values[np.isfinite(pred_da.values)],
# ])

# if vals_all.size > 0:
#     vmin, vmax = np.nanpercentile(vals_all, [2, 98])
# else:
#     vmin, vmax = 0.0, 1.0

# # -----------------------------
# # Plot: two panels + one colorbar
# # -----------------------------
# fig, axes = plt.subplots(1, 2, figsize=(15, 6), constrained_layout=False)

# # GOES
# im0 = goes_scaled.plot.imshow(
#     ax=axes[0],
#     cmap="viridis",
#     add_colorbar=False,
#     vmin=vmin,
#     vmax=vmax,
# )
# axes[0].set_title("GOES-R LSAC 2km Blue-sky Albedo")
# axes[0].set_xlabel("Longitude")
# axes[0].set_ylabel("Latitude")
# axes[0].tick_params(axis="x", rotation=25)

# # MODIS
# im1 = modis_da.plot.imshow(
#     ax=axes[1],
#     cmap="viridis",
#     add_colorbar=False,
#     vmin=vmin,
#     vmax=vmax,
# )
# axes[1].set_title("MODIS 500m Blue-sky Albedo")
# axes[1].set_xlabel("Longitude")
# axes[1].set_ylabel("Latitude")
# axes[1].tick_params(axis="x", rotation=25)

# # Shared colorbar on the right
# cax = fig.add_axes([0.92, 0.15, 0.015, 0.7])
# cbar = fig.colorbar(im1, cax=cax)
# cbar.set_label("Blue-sky Albedo")

# plt.subplots_adjust(right=0.9, wspace=0.25)
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import rioxarray as rxr
# from pyproj import Transformer

goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2021/331/18/OR_ABI-L2-LSAC-M6_G16_s20213311826176_e20213311828549_c20213311829572.nc"
modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2021331_modis_blue_sky_albedo_.tif"
goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-05-06_modis_blue_sky_albedo_.tif"

# -----------------------------
# GOES: keep in UTM, clip + scale
# -----------------------------
goes_rxr = rxr.open_rasterio(goes_blue_sky, masked=True)
goes_reprojected = goes_rxr.rio.reproject("EPSG:32613")

goes_clipped = (
    goes_reprojected["LSA"]
    .rio.clip(boundary_box_utm, all_touched=True, from_disk=True, drop=True)
    .squeeze()
)

scale_factor = 0.0001
goes_scaled = goes_clipped * scale_factor

# -----------------------------
# MODIS & predicted MODIS
# -----------------------------
modis_da = rxr.open_rasterio(modis_blue_sky, masked=True)
if "band" in modis_da.dims:
    modis_da = modis_da.sel(band=1, drop=True)

pred_da = rxr.open_rasterio(goes_blue_sky_predicted, masked=True)
if "band" in pred_da.dims:
    pred_da = pred_da.sel(band=1, drop=True)

def clip01(a):
    return a.clip(min=0.0, max=1.0)

goes_scaled = clip01(goes_scaled)
modis_da    = clip01(modis_da)
pred_da     = clip01(pred_da)

# -----------------------------
# Shared vmin/vmax
# -----------------------------
vals_all = np.concatenate([
    goes_scaled.values[np.isfinite(goes_scaled.values)],
    modis_da.values[np.isfinite(modis_da.values)],
    pred_da.values[np.isfinite(pred_da.values)],
])

if vals_all.size > 0:
    vmin, vmax = np.nanpercentile(vals_all, [2, 98])
else:
    vmin, vmax = 0.0, 1.0

# -----------------------------
# Plot
# -----------------------------
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

im0 = goes_scaled.plot.imshow(
    ax=axes[0],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[0].set_title("GOES-R LSAC 2km Blue-sky Albedo")

im1 = modis_da.plot.imshow(
    ax=axes[1],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[1].set_title("MODIS 500m Blue-sky Albedo")

transformer = Transformer.from_crs("EPSG:32613", "EPSG:4326", always_xy=True)

def set_lon_lat_axes_from_bounds(ax, da, n_xticks=6, n_yticks=6):
    # exact raster bounds in UTM
    xmin, ymin, xmax, ymax = da.rio.bounds()

    # force axes to match raster extent exactly
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    # make ticks only inside the raster footprint
    xticks = np.linspace(xmin, xmax, n_xticks)
    yticks = np.linspace(ymin, ymax, n_yticks)

    # convert ticks to lon/lat labels
    ymid = 0.5 * (ymin + ymax)
    lon_labels = [f"{transformer.transform(x, ymid)[0]:.2f}" for x in xticks]

    xmid = 0.5 * (xmin + xmax)
    lat_labels = [f"{transformer.transform(xmid, y)[1]:.2f}" for y in yticks]

    ax.set_xticks(xticks)
    ax.set_yticks(yticks)
    ax.set_xticklabels(lon_labels, rotation=25)
    ax.set_yticklabels(lat_labels)

    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")

    # no extra margins
    ax.margins(0)

set_lon_lat_axes_from_bounds(axes[0], goes_scaled)
set_lon_lat_axes_from_bounds(axes[1], modis_da)

# # cleaner shared colorbar
# cbar = fig.colorbar(im1, ax=axes, fraction=0.03, pad=0.02)
# cbar.set_label("Blue-sky Albedo")

# Shared colorbar on the right
cax = fig.add_axes([0.92, 0.15, 0.015, 0.7])  # [left, bottom, width, height]
cbar = fig.colorbar(im1, cax=cax)
cbar.set_label("Blue-sky Albedo")

fig.subplots_adjust(right=0.88, wspace=0.25)
# plt.tight_layout()


# fig.subplots_adjust(wspace=0.28, right=0.88)
# cax = fig.add_axes([0.90, 0.12, 0.018, 0.76])
# cbar = fig.colorbar(im1, cax=cax)
# cbar.set_label("Blue-sky Albedo")

# plt.tight_layout()
plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import rioxarray as rxr
# import geopandas as gpd

# from pyproj import Transformer


# ============================================================
# File paths
# ============================================================

goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2021/331/18/OR_ABI-L2-LSAC-M6_G16_s20213311826176_e20213311828549_c20213311829572.nc"

modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2021331_modis_blue_sky_albedo_.tif"

goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-05-06_modis_blue_sky_albedo_.tif"

kml_path = "/bsuhome/tnde/geoscience/albedo_downscaling/shape_files/East_River.kml"

# Use the layer name that worked for you.
# If your KML opens without a layer name, set this to None.
kml_layer = "East_River.kml"
# kml_layer = None


# ============================================================
# Read KML study area boundary
# ============================================================

if kml_layer is None:
    study_area = gpd.read_file(kml_path)
else:
    study_area = gpd.read_file(kml_path, layer=kml_layer)

study_area = study_area[
    study_area.geometry.notnull() & ~study_area.geometry.is_empty
].copy()

# Only assign CRS if GeoPandas did not detect one.
# Your KML is already lon/lat, so this only labels it correctly.
if study_area.crs is None:
    study_area = study_area.set_crs("EPSG:4326")

print("KML CRS:", study_area.crs)
print(study_area.head())


# ============================================================
# GOES: open, reproject to UTM, clip using ORIGINAL bbox, scale
# ============================================================

target_crs = "EPSG:32613"

goes_rxr = rxr.open_rasterio(goes_blue_sky, masked=True)

# Reproject GOES to UTM Zone 13N
goes_reprojected = goes_rxr.rio.reproject(target_crs)

# IMPORTANT:
# Use your original rectangular/study-area bbox clip here.
# Do NOT use the KML geometry to clip GOES if you want to keep
# the same layout as the original image.
goes_clipped = (
    goes_reprojected["LSA"]
    .rio.clip(
        boundary_box_utm,
        all_touched=True,
        from_disk=True,
        drop=True
    )
    .squeeze()
)

# Reattach CRS after selecting/clipping
goes_clipped = goes_clipped.rio.write_crs(target_crs)

# Scale GOES albedo
scale_factor = 0.0001
goes_scaled = goes_clipped * scale_factor

# Arithmetic can sometimes drop CRS metadata
goes_scaled = goes_scaled.rio.write_crs(target_crs)


# ============================================================
# MODIS and predicted MODIS
# ============================================================

modis_da = rxr.open_rasterio(modis_blue_sky, masked=True)
if "band" in modis_da.dims:
    modis_da = modis_da.sel(band=1, drop=True)

pred_da = rxr.open_rasterio(goes_blue_sky_predicted, masked=True)
if "band" in pred_da.dims:
    pred_da = pred_da.sel(band=1, drop=True)


# ============================================================
# Clip albedo values to 0-1 range
# ============================================================

def clip01(a):
    return a.clip(min=0.0, max=1.0)

goes_scaled = clip01(goes_scaled).rio.write_crs(target_crs)
modis_da = clip01(modis_da)
pred_da = clip01(pred_da)


# ============================================================
# Make sure raster CRS values exist
# ============================================================

print("GOES CRS:", goes_scaled.rio.crs)
print("MODIS CRS:", modis_da.rio.crs)

if modis_da.rio.crs is None:
    # Only keep this if you know your MODIS GeoTIFF is in UTM Zone 13N.
    modis_da = modis_da.rio.write_crs(target_crs)


# ============================================================
# Reproject KML boundary for overlay only
# ============================================================

study_area_goes = study_area.to_crs(goes_scaled.rio.crs)
study_area_modis = study_area.to_crs(modis_da.rio.crs)


# ============================================================
# Shared vmin/vmax
# ============================================================

vals_all = np.concatenate([
    goes_scaled.values[np.isfinite(goes_scaled.values)],
    modis_da.values[np.isfinite(modis_da.values)],
    pred_da.values[np.isfinite(pred_da.values)],
])

if vals_all.size > 0:
    vmin, vmax = np.nanpercentile(vals_all, [2, 98])
else:
    vmin, vmax = 0.0, 1.0

print("vmin:", vmin)
print("vmax:", vmax)


# ============================================================
# Helper functions
# ============================================================

def set_lon_lat_axes_from_current_limits(
    ax,
    src_crs,
    n_xticks=6,
    n_yticks=6
):
    """
    Keep the current raster plot limits exactly as they are,
    but label the ticks as longitude/latitude.
    """

    xmin, xmax = ax.get_xlim()
    ymin, ymax = ax.get_ylim()

    xticks = np.linspace(xmin, xmax, n_xticks)
    yticks = np.linspace(ymin, ymax, n_yticks)

    transformer = Transformer.from_crs(
        src_crs,
        "EPSG:4326",
        always_xy=True
    )

    ymid = 0.5 * (ymin + ymax)
    lon_labels = [
        f"{transformer.transform(x, ymid)[0]:.2f}"
        for x in xticks
    ]

    xmid = 0.5 * (xmin + xmax)
    lat_labels = [
        f"{transformer.transform(xmid, y)[1]:.2f}"
        for y in yticks
    ]

    ax.set_xticks(xticks)
    ax.set_yticks(yticks)

    ax.set_xticklabels(lon_labels, rotation=25)
    ax.set_yticklabels(lat_labels)

    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")

    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    ax.margins(0)


def overlay_kml_boundary_without_rescaling(
    ax,
    boundary_gdf,
    color="red",
    linewidth=2.5
):
    """
    Plot KML boundary without allowing it to change the axis extent.
    This keeps the original raster layout.
    """

    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    boundary_gdf.boundary.plot(
        ax=ax,
        color=color,
        linewidth=linewidth,
        zorder=10
    )

    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.set_autoscale_on(False)


# ============================================================
# Plot GOES and MODIS with KML boundary overlay
# ============================================================

fig, axes = plt.subplots(1, 2, figsize=(15, 6))


# -----------------------------
# GOES plot
# -----------------------------

im0 = goes_scaled.plot.imshow(
    ax=axes[0],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax
)

axes[0].set_title("GOES-R LSAC 2km Blue-sky Albedo")

overlay_kml_boundary_without_rescaling(
    ax=axes[0],
    boundary_gdf=study_area_goes,
    color="red",
    linewidth=2.5
)

set_lon_lat_axes_from_current_limits(
    ax=axes[0],
    src_crs=goes_scaled.rio.crs
)


# -----------------------------
# MODIS plot
# -----------------------------

im1 = modis_da.plot.imshow(
    ax=axes[1],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax
)

axes[1].set_title("MODIS 500m Blue-sky Albedo")

overlay_kml_boundary_without_rescaling(
    ax=axes[1],
    boundary_gdf=study_area_modis,
    color="red",
    linewidth=2.5
)

set_lon_lat_axes_from_current_limits(
    ax=axes[1],
    src_crs=modis_da.rio.crs
)


# -----------------------------
# Shared colorbar
# -----------------------------

fig.subplots_adjust(right=0.90, wspace=0.25)
# plt.tight_layout()

cax = fig.add_axes([0.92, 0.15, 0.015, 0.7])
cbar = fig.colorbar(im1, cax=cax)
cbar.set_label("Blue-sky Albedo")

plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import rioxarray as rxr
# from pyproj import Transformer

# plt.style.use("default")

# goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/012/18/OR_ABI-L2-LSAC-M6_G16_s20230121826172_e20230121828545_c20230121830487.nc"
# modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2021331_modis_blue_sky_albedo_.tif"
# goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-01-12_modis_blue_sky_albedo_.tif"

goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/126/18/OR_ABI-L2-LSAC-M6_G16_s20231261826171_e20231261828544_c20231261830209.nc"
modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2023126_modis_blue_sky_albedo_.tif"
goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-05-06_modis_blue_sky_albedo_.tif"

# goes_blue_sky = "/bsuhome/tnde/scratch/felix/GOES/data/ABI-L2-LSAC/2023/156/18/OR_ABI-L2-LSAC-M6_G16_s20231561826179_e20231561828552_c20231561830350.nc"
# modis_blue_sky = "/bsuhome/tnde/scratch/felix/modis/blue_sky_albedo_sail_new/2023156_modis_blue_sky_albedo_.tif"
# goes_blue_sky_predicted = "/bsuhome/tnde/scratch/felix/UNet/Unet_test_preds_modis_new/predicted_2023-06-05_modis_blue_sky_albedo_.tif"

# -----------------------------
# GOES: reproject + clip + scale
# -----------------------------
goes_rxr = rxr.open_rasterio(goes_blue_sky, masked=True)
goes_reprojected = goes_rxr.rio.reproject("EPSG:32613")

goes_clipped = (
    goes_reprojected["LSA"]
    .rio.clip(boundary_box_utm, all_touched=True, from_disk=True, drop=True)
    .squeeze()
)

scale_factor = 0.0001
goes_scaled = goes_clipped * scale_factor

# -----------------------------
# MODIS & predicted MODIS
# -----------------------------
modis_da = rxr.open_rasterio(modis_blue_sky, masked=True)
if "band" in modis_da.dims:
    modis_da = modis_da.sel(band=1, drop=True)

pred_da = rxr.open_rasterio(goes_blue_sky_predicted, masked=True)
if "band" in pred_da.dims:
    pred_da = pred_da.sel(band=1, drop=True)

# Optional physical clipping
def clip01(a):
    return a.clip(min=0.0, max=1.0)

goes_scaled = clip01(goes_scaled)
modis_da    = clip01(modis_da)
pred_da     = clip01(pred_da)

# -----------------------------
# Shared vmin/vmax across all three
# -----------------------------
vals_all = np.concatenate([
    goes_scaled.values[np.isfinite(goes_scaled.values)],
    modis_da.values[np.isfinite(modis_da.values)],
    pred_da.values[np.isfinite(pred_da.values)],
])

if vals_all.size > 0:
    vmin, vmax = np.nanpercentile(vals_all, [2, 98])
else:
    vmin, vmax = 0.0, 1.0

# -----------------------------
# Helper: relabel UTM axes as lon/lat
# -----------------------------
transformer = Transformer.from_crs("EPSG:32613", "EPSG:4326", always_xy=True)

def set_lon_lat_axes_from_bounds(ax, da, n_xticks=5, n_yticks=5):
    xmin, ymin, xmax, ymax = da.rio.bounds()

    # force axes to raster bounds
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    # ticks strictly within bounds
    xticks = np.linspace(xmin, xmax, n_xticks)
    yticks = np.linspace(ymin, ymax, n_yticks)

    # longitude labels from x ticks at mid y
    ymid = 0.5 * (ymin + ymax)
    lon_labels = [f"{transformer.transform(x, ymid)[0]:.2f}" for x in xticks]

    # latitude labels from y ticks at mid x
    xmid = 0.5 * (xmin + xmax)
    lat_labels = [f"{transformer.transform(xmid, y)[1]:.2f}" for y in yticks]

    ax.set_xticks(xticks)
    ax.set_yticks(yticks)
    ax.set_xticklabels(lon_labels, rotation=25)
    ax.set_yticklabels(lat_labels)

    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    ax.margins(0)

# -----------------------------
# Plot: three panels + one colorbar
# -----------------------------
fig, axes = plt.subplots(1, 3, figsize=(15, 4), constrained_layout=False)

# GOES
im0 = goes_scaled.plot.imshow(
    ax=axes[0],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[0].set_title("GOES LSAC Blue-sky Albedo")
set_lon_lat_axes_from_bounds(axes[0], goes_scaled)

# MODIS
im1 = modis_da.plot.imshow(
    ax=axes[1],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[1].set_title("MODIS Blue-sky Albedo")
set_lon_lat_axes_from_bounds(axes[1], modis_da)

# Predicted MODIS (U-Net)
im2 = pred_da.plot.imshow(
    ax=axes[2],
    cmap="viridis",
    add_colorbar=False,
    vmin=vmin,
    vmax=vmax,
)
axes[2].set_title("U-Net Predicted GOES-R Blue-sky Albedo")
set_lon_lat_axes_from_bounds(axes[2], pred_da)

# Standalone colorbar on the right
fig.subplots_adjust(right=0.89, wspace=0.30)
cax = fig.add_axes([0.91, 0.15, 0.015, 0.70])
cbar = fig.colorbar(im2, cax=cax)
cbar.set_label("Blue-sky Albedo")

plt.subplots_adjust(right=0.9, wspace=0.25)
plt.show()
